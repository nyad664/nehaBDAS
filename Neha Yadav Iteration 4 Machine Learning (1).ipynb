# %%
#PART 1: INTRODUCING THE DATA SET 
#importing panda and matplot
import pandas as pd
import matplotlib.pyplot as plt
#allows plot to apeear
# %matplotlib inline
#creating data frame
rta = pd.read_csv('Datasets/Kaagle_Upload.csv')
# Out:
# /home/ubuntu/.local/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
rta.head()
#Nan- Missing values ,may be not recorded at that time
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1 accident_index  vehicle_reference  \
# 0           0             0               0  201506E098757                  2
# 1           1             1               1  201506E098766                  1
# 2           2             2               2  201506E098766                  2
# 3           3             3               3  201506E098777                  1
# 4           4             4               4  201506E098780                  1
#
#    vehicle_type  towing_and_articulation  vehicle_manoeuvre  \
# 0             9                        0                 18
# 1             9                        0                  9
# 2             9                        0                 18
# 3            20                        0                  4
# 4             9                        0                 15
#
#    vehicle_location-restricted_lane  junction_location  \
# 0                                 0                  8
# ...

# %%
rta.shape
# Out:
# (285331, 53)

# %%
rta.dtypes
#object-string, float-floating point number
# Out:
# Unnamed: 0                                           int64
# Unnamed: 0.1                                         int64
# Unnamed: 0.1.1                                       int64
# accident_index                                      object
# vehicle_reference                                    int64
# vehicle_type                                         int64
# towing_and_articulation                              int64
# vehicle_manoeuvre                                    int64
# vehicle_location-restricted_lane                     int64
# junction_location                                    int64
# skidding_and_overturning                             int64
# hit_object_in_carriageway                            int64
# vehicle_leaving_carriageway                          int64
# hit_object_off_carriageway                           int64
# 1st_point_of_impact                                  int64
# was_vehicle_left_hand_drive?                         int64
# ...

# %%
rta.isnull().sum()
#the count of missing data in each value;sum all the values down
# Out:
# Unnamed: 0                                          0
# Unnamed: 0.1                                        0
# Unnamed: 0.1.1                                      0
# accident_index                                      0
# vehicle_reference                                   0
# vehicle_type                                        0
# towing_and_articulation                             0
# vehicle_manoeuvre                                   0
# vehicle_location-restricted_lane                    0
# junction_location                                   0
# skidding_and_overturning                            0
# hit_object_in_carriageway                           0
# vehicle_leaving_carriageway                         0
# hit_object_off_carriageway                          0
# 1st_point_of_impact                                 0
# was_vehicle_left_hand_drive?                        0
# journey_purpose_of_driver                           0
# ...

# %%
rta.isnull()
# Out:
#         Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  accident_index  \
# 0            False         False           False           False
# 1            False         False           False           False
# 2            False         False           False           False
# 3            False         False           False           False
# 4            False         False           False           False
# 5            False         False           False           False
# 6            False         False           False           False
# 7            False         False           False           False
# 8            False         False           False           False
# 9            False         False           False           False
# 10           False         False           False           False
# 11           False         False           False           False
# 12           False         False           False           False
# ...

# %%
# PART 2: REMOVING COLUMNS CONTAINING MISSING VALUES

# %%
rta.shape
# Out:
# (285331, 53)

# %%
rta.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.1.1', 'accident_index',
#        'vehicle_reference', 'vehicle_type', 'towing_and_articulation',
#        'vehicle_manoeuvre', 'vehicle_location-restricted_lane',
#        'junction_location', 'skidding_and_overturning',
#        'hit_object_in_carriageway', 'vehicle_leaving_carriageway',
#        'hit_object_off_carriageway', '1st_point_of_impact',
#        'was_vehicle_left_hand_drive?', 'journey_purpose_of_driver',
#        'sex_of_driver', 'age_of_driver', 'age_band_of_driver',
#        'engine_capacity_(cc)', 'propulsion_code', 'age_of_vehicle',
#        'driver_imd_decile', 'driver_home_area_type', 'vehicle_imd_decile',
#        'NUmber_of_Casualities_unique_to_accident_index',
#        'No_of_Vehicles_involved_unique_to_accident_index', 'police_force',
#        'accident_severity', 'number_of_vehicles', 'number_of_casualties',
#        'date', 'day_of_week', 'local_authority_(district)',
# ...

# %%
#method 2
rta.dropna(axis='columns', how='all').shape
# Out:
# (285331, 53)

# %%
rta.isnull().sum()
# Out:
# Unnamed: 0                                          0
# Unnamed: 0.1                                        0
# Unnamed: 0.1.1                                      0
# accident_index                                      0
# vehicle_reference                                   0
# vehicle_type                                        0
# towing_and_articulation                             0
# vehicle_manoeuvre                                   0
# vehicle_location-restricted_lane                    0
# junction_location                                   0
# skidding_and_overturning                            0
# hit_object_in_carriageway                           0
# vehicle_leaving_carriageway                         0
# hit_object_off_carriageway                          0
# 1st_point_of_impact                                 0
# was_vehicle_left_hand_drive?                        0
# journey_purpose_of_driver                           0
# ...

# %%
rta.shape
# Out:
# (285331, 53)

# %%
rta.isnull().sum()
# Out:
# Unnamed: 0                                          0
# Unnamed: 0.1                                        0
# Unnamed: 0.1.1                                      0
# accident_index                                      0
# vehicle_reference                                   0
# vehicle_type                                        0
# towing_and_articulation                             0
# vehicle_manoeuvre                                   0
# vehicle_location-restricted_lane                    0
# junction_location                                   0
# skidding_and_overturning                            0
# hit_object_in_carriageway                           0
# vehicle_leaving_carriageway                         0
# hit_object_off_carriageway                          0
# 1st_point_of_impact                                 0
# was_vehicle_left_hand_drive?                        0
# journey_purpose_of_driver                           0
# ...

# %%
rta.isnull()
# Out:
#         Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  accident_index  \
# 0            False         False           False           False
# 1            False         False           False           False
# 2            False         False           False           False
# 3            False         False           False           False
# 4            False         False           False           False
# 5            False         False           False           False
# 6            False         False           False           False
# 7            False         False           False           False
# 8            False         False           False           False
# 9            False         False           False           False
# 10           False         False           False           False
# 11           False         False           False           False
# 12           False         False           False           False
# ...

# %%
rta.isnull().sum()
# Out:
# Unnamed: 0                                          0
# Unnamed: 0.1                                        0
# Unnamed: 0.1.1                                      0
# accident_index                                      0
# vehicle_reference                                   0
# vehicle_type                                        0
# towing_and_articulation                             0
# vehicle_manoeuvre                                   0
# vehicle_location-restricted_lane                    0
# junction_location                                   0
# skidding_and_overturning                            0
# hit_object_in_carriageway                           0
# vehicle_leaving_carriageway                         0
# hit_object_off_carriageway                          0
# 1st_point_of_impact                                 0
# was_vehicle_left_hand_drive?                        0
# journey_purpose_of_driver                           0
# ...

# %%
#filter for a particular and select on that basis

# %%
rta.groupby('sex_of_driver').accident_severity.value_counts(normalize=True)
# Out:
# sex_of_driver  accident_severity
# -1             3                    0.900000
#                2                    0.100000
#  1             3                    0.834322
#                2                    0.150205
#                1                    0.015473
#  2             3                    0.881361
#                2                    0.110622
#                1                    0.008017
#  3             3                    0.870533
#                2                    0.123711
#                1                    0.005757
# Name: accident_severity, dtype: float64

# %%
rta.groupby('sex_of_driver').speed_limit.value_counts(normalize=True)
# Out:
# sex_of_driver  speed_limit
# -1             30             0.500000
#                60             0.250000
#                70             0.100000
#                0              0.050000
#                20             0.050000
#                40             0.050000
#  1             30             0.607202
#                60             0.142751
#                40             0.089866
#                70             0.087509
#                50             0.045762
#                20             0.026893
#                10             0.000011
#                0              0.000005
#  2             30             0.603974
#                60             0.143331
#                40             0.098041
#                70             0.082094
#                50             0.047769
#                20             0.024779
#                10             0.000012
#  3             30             0.735968
#                60             0.078556
# ...

# %%
rta.groupby('sex_of_driver').accident_severity.value_counts(normalize=True).unstack()
# Out:
# accident_severity         1         2         3
# sex_of_driver
# -1                      NaN  0.100000  0.900000
#  1                 0.015473  0.150205  0.834322
#  2                 0.008017  0.110622  0.881361
#  3                 0.005757  0.123711  0.870533

# %%
rta.groupby('sex_of_driver').speed_limit.value_counts(normalize=True).unstack()
# Out:
# speed_limit          0         10        20        30        40        50  \
# sex_of_driver
# -1             0.050000       NaN  0.050000  0.500000  0.050000       NaN
#  1             0.000005  0.000011  0.026893  0.607202  0.089866  0.045762
#  2                  NaN  0.000012  0.024779  0.603974  0.098041  0.047769
#  3                  NaN       NaN  0.044855  0.735968  0.066263  0.026565
#
# speed_limit          60        70
# sex_of_driver
# -1             0.250000  0.100000
#  1             0.142751  0.087509
#  2             0.143331  0.082094
#  3             0.078556  0.047793

# %%
#PART 3 : EXAMING RELATIONSHIP

# %%
rta.age_band_of_driver.value_counts(normalize=True)
# Out:
#  6     0.208631
#  7     0.174334
#  8     0.156818
#  5     0.115242
# -1     0.106115
#  9     0.085697
#  4     0.075407
#  10    0.043928
#  11    0.026587
#  3     0.005471
#  2     0.001535
#  1     0.000235
# Name: age_band_of_driver, dtype: float64

# %%
rta.age_band_of_driver.mean()
# Out:
# 6.021115826881762

# %%
# For each sex of the driver I need tha age band

# %%
rta.groupby('sex_of_driver').age_band_of_driver.mean()
# Out:
# sex_of_driver
# -1    1.050000
#  1    6.370869
#  2    6.550729
#  3   -0.481590
# Name: age_band_of_driver, dtype: float64

# %%
# we get the summary detail
rta.groupby(['sex_of_driver','accident_severity']).speed_limit.mean()
# Out:
# sex_of_driver  accident_severity
# -1             2                    45.000000
#                3                    39.444444
#  1             1                    50.389387
#                2                    41.891594
#                3                    38.660749
#  2             1                    50.707692
#                2                    41.824061
#                3                    38.847031
#  3             1                    41.666667
#                2                    35.637421
#                3                    34.881174
# Name: speed_limit, dtype: float64

# %%
# Handling Missing Values or Filterning the Data Set
rta.accident_severity.value_counts(dropna=False)
# Out:
# 3    242477
# 2     39206
# 1      3648
# Name: accident_severity, dtype: int64

# %%
# Plotting

# %%
rta.day_of_week.mean()
# Out:
# 4.097686546502133

# %%
rta.groupby('day_of_week').speed_limit.mean()
# Out:
# day_of_week
# 1    39.946733
# 2    39.270693
# 3    38.655669
# 4    38.855662
# 5    38.651267
# 6    39.236331
# 7    39.041690
# Name: speed_limit, dtype: float64

# %%
rta.groupby('accident_severity').day_of_week.mean()
# Out:
# accident_severity
# 1    3.989035
# 2    4.099653
# 3    4.099003
# Name: day_of_week, dtype: float64

# %%
rta.groupby('date').day_of_week.mean()
# Out:
# date
# 13/01/2015    3.000000
# 13/02/2015    6.000000
# 13/03/2015    6.000000
# 13/04/2015    2.000000
# 13/05/2015    3.996016
# 13/06/2015    7.000000
# 13/07/2015    2.000000
# 13/08/2015    5.000000
# 13/09/2015    1.000000
# 13/10/2015    3.000000
# 13/11/2015    6.000000
# 13/12/2015    1.000000
# 14/01/2015    4.000000
# 14/02/2015    7.000000
# 14/03/2015    7.000000
# 14/04/2015    3.000000
# 14/05/2015    5.000000
# 14/06/2015    1.000000
# 14/07/2015    3.000000
# 14/08/2015    6.000000
# 14/09/2015    2.000000
# 14/10/2015    4.000000
# 14/11/2015    7.000000
# 14/12/2015    2.000000
# 15/01/2015    5.000000
# 15/02/2015    1.000000
# 15/03/2015    1.000000
# 15/04/2015    4.000000
# 15/05/2015    6.000000
# 15/06/2015    2.000000
#                 ...
# 42284         6.000000
# 42285         2.000000
# 42286         5.000000
# 42287         7.000000
# 42288         3.000000
# 42289         5.000000
# 42309         1.000000
# 42310         4.000000
# ...

# %%
rta.groupby('day_of_week').speed_limit.mean().plot()

# %%
rta.groupby('accident_severity').day_of_week.mean().plot()

# %%
rta.groupby('accident_severity').speed_limit.mean().plot()

# %%
rta.groupby('accident_severity').weather_conditions.mean().plot()

# %%
rta.groupby('accident_severity').road_surface_conditions.mean().plot()

# %%
rta.groupby('accident_severity').accident_severity.mean().plot()

# %%
rta.groupby('age_band_of_driver').speed_limit.mean().plot()

# %%
rta.groupby('age_band_of_driver').speed_limit.mean().sort_index
# Out:
# <bound method Series.sort_index of age_band_of_driver
# -1     34.084484
#  1     29.253731
#  2     29.817352
#  3     30.762332
#  4     39.859639
#  5     39.695578
#  6     38.983689
#  7     39.363931
#  8     40.278467
#  9     40.623262
#  10    40.808202
#  11    39.696810
# Name: speed_limit, dtype: float64>

# %%
rta.isnull()
# Out:
#         Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  accident_index  \
# 0            False         False           False           False
# 1            False         False           False           False
# 2            False         False           False           False
# 3            False         False           False           False
# 4            False         False           False           False
# 5            False         False           False           False
# 6            False         False           False           False
# 7            False         False           False           False
# 8            False         False           False           False
# 9            False         False           False           False
# 10           False         False           False           False
# 11           False         False           False           False
# 12           False         False           False           False
# ...

# %%
# compating numercial values and exploring

# %%
rta[(rta.speed_limit > 50) & (rta.speed_limit < 80)].shape
# Out:
# (63578, 53)

# %%
rta.shape
# Out:
# (285331, 53)

# %%
rta.isnull()
# Out:
#         Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  accident_index  \
# 0            False         False           False           False
# 1            False         False           False           False
# 2            False         False           False           False
# 3            False         False           False           False
# 4            False         False           False           False
# 5            False         False           False           False
# 6            False         False           False           False
# 7            False         False           False           False
# 8            False         False           False           False
# 9            False         False           False           False
# 10           False         False           False           False
# 11           False         False           False           False
# 12           False         False           False           False
# ...

# %%
import findspark
findspark.init('/home/ubuntu/spark-2.1.1-bin-hadoop2.7')
import pyspark
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('basics').getOrCreate()

# %%
df = spark.read.csv('Datasets/Kaagle_Upload.csv',header=True,inferSchema=True)
df.show()
# Out:
# +---+----------+------------+--------------+-----------------+------------+-----------------------+-----------------+--------------------------------+-----------------+------------------------+-------------------------+---------------------------+--------------------------+-------------------+----------------------------+-------------------------+-------------+-------------+------------------+--------------------+---------------+--------------+-----------------+---------------------+------------------+----------------------------------------------+------------------------------------------------+------------+-----------------+------------------+--------------------+----------+-----------+--------------------------+-------------------------+--------------+---------------+---------+-----------+---------------+----------------+--------------+---------------+---------------------------------+---------------------------------------+----------------+------------------+---------------------
# ...

# %%
df.printSchema()
# Out:
# root
#  |-- _c0: integer (nullable = true)
#  |-- Unnamed: 0: integer (nullable = true)
#  |-- Unnamed: 0.1: integer (nullable = true)
#  |-- accident_index: string (nullable = true)
#  |-- vehicle_reference: integer (nullable = true)
#  |-- vehicle_type: integer (nullable = true)
#  |-- towing_and_articulation: integer (nullable = true)
#  |-- vehicle_manoeuvre: integer (nullable = true)
#  |-- vehicle_location-restricted_lane: integer (nullable = true)
#  |-- junction_location: integer (nullable = true)
#  |-- skidding_and_overturning: integer (nullable = true)
#  |-- hit_object_in_carriageway: integer (nullable = true)
#  |-- vehicle_leaving_carriageway: integer (nullable = true)
#  |-- hit_object_off_carriageway: integer (nullable = true)
#  |-- 1st_point_of_impact: integer (nullable = true)
#  |-- was_vehicle_left_hand_drive?: integer (nullable = true)
#  |-- journey_purpose_of_driver: integer (nullable = true)
#  |-- sex_of_driver: integer (nullable = true)
# ...

# %%
#selecting

# %%
from pyspark.sql import *
spark = SparkSession.builder.appName('logistic_regression_adv').getOrCreate()

# %%
# Import the relevant packages

# %%
from pyspark.ml.feature import (VectorAssembler,VectorIndexer,OneHotEncoder,StringIndexer)

# %%
ur_indexer = StringIndexer(inputCol='urban_or_rural_area',outputCol='urbanrural')
weather_indexer = StringIndexer(inputCol='weather_conditions',outputCol='weather')
driversex_indexer = StringIndexer(inputCol='sex_of_driver',outputCol='driversex')
rsc_indexer = StringIndexer(inputCol='road_surface_conditions',outputCol='rsc')
sl_indexer = StringIndexer(inputCol='speed_limit',outputCol='sl')
accidentseverity_indexer = StringIndexer(inputCol='accident_severity',outputCol='label')

# %%
urru_encoder = OneHotEncoder(inputCol='urbanrural',outputCol='urbanruralVec')
weather_encoder = OneHotEncoder(inputCol='weather',outputCol='weatherVec')
driversex_encoder = OneHotEncoder(inputCol='driversex',outputCol='driversexVec')
rsc_encoder = StringIndexer(inputCol='rsc',outputCol='rscVec')
sl_encoder = StringIndexer(inputCol='sl',outputCol='slVec')
label_encoder = StringIndexer(inputCol='label',outputCol='label')

# %%
assembler = VectorAssembler(inputCols=['urbanruralVec','weatherVec','driversexVec',
                                       'rscVec','slVec'], outputCol="features")

# %%
#pipeline

# %%
from pyspark.ml import Pipeline

# %%
pipeline = Pipeline(stages=[ur_indexer,weather_indexer,driversex_indexer,rsc_indexer,sl_indexer,accidentseverity_indexer,
                            urru_encoder,weather_encoder,driversex_encoder,rsc_encoder,sl_encoder,assembler])

# %%
pipeline_model = pipeline.fit(df)

# %%
pipe_df = pipeline_model.transform(df)

# %%
pipe_df = pipe_df.select('label','features')

# %%
pipe_df.describe()
# Out:
# DataFrame[summary: string, label: string]

# %%
from pyspark.ml.classification import LogisticRegression

# %%
train_data, test_data = pipe_df.randomSplit([0.7,0.3])
print("Training Dataset Count: " + str(train_data.count()))
print("Test Dataset Count: " + str(test_data.count()))
# Out:
# Training Dataset Count: 199657
# Test Dataset Count: 85674

# %%
# Random Forest  ITERATON 3

# %%
from pyspark.ml.classification import *
from pyspark.ml.evaluation import BinaryClassificationEvaluator
rf = RandomForestClassifier(featuresCol = 'features', labelCol = 'label')
rfModel = rf.fit(train_data)
predictions = rfModel.transform(test_data)

# %%
from pyspark.ml.evaluation import MulticlassClassificationEvaluator

# %%
evaluator = MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction",metricName="accuracy")
accuracy = evaluator.evaluate(predictions)
print("Test set accuracy = " + str(accuracy))
# Out:
# Test set accuracy = 0.8508065457431659

# %%
# Bayesian  ITERATION 3

# %%
from pyspark.ml.classification import NaiveBayes
from pyspark.ml.evaluation import MulticlassClassificationEvaluator

# create the trainer and set its parameters
nb = NaiveBayes(smoothing=1.0, modelType="multinomial")

# train the model
model = nb.fit(train_data)

# select example rows to display.
predictions = model.transform(test_data)
#predictions.show()

# compute accuracy on the test set
#evaluator = MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction",metricName="accuracy")
accuracy = evaluator.evaluate(predictions)
#print("Test set accuracy = " + str(accuracy))

evaluator = BinaryClassificationEvaluator()
print("Test Area Under ROC: " + str(evaluator.evaluate(predictions, {evaluator.metricName: "areaUnderROC"})))
# Out:
# Test Area Under ROC: 0.5162453498291086

# %%
# Bayesian  ITERATION 2

# %%
from pyspark.ml.classification import NaiveBayes
from pyspark.ml.evaluation import MulticlassClassificationEvaluator

# create the trainer and set its parameters
nb = NaiveBayes(smoothing=0.5, modelType="multinomial")

# train the model
model = nb.fit(train_data)

# select example rows to display.
predictions = model.transform(test_data)
#predictions.show()

# compute accuracy on the test set
#evaluator = MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction",metricName="accuracy")
accuracy = evaluator.evaluate(predictions)
#print("Test set accuracy = " + str(accuracy))

evaluator = BinaryClassificationEvaluator()
print("Test Area Under ROC: " + str(evaluator.evaluate(predictions, {evaluator.metricName: "areaUnderROC"})))
# Out:
# Test Area Under ROC: 0.5162930108098618

# %%
# Bayesian  ITERATION 1

# %%
from pyspark.ml.classification import NaiveBayes
from pyspark.ml.evaluation import MulticlassClassificationEvaluator

# create the trainer and set its parameters
nb = NaiveBayes(smoothing=2.5, modelType="multinomial")

# train the model
model = nb.fit(train_data)

# select example rows to display.
predictions = model.transform(test_data)
#predictions.show()

# compute accuracy on the test set
#evaluator = MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction",metricName="accuracy")
accuracy = evaluator.evaluate(predictions)
#print("Test set accuracy = " + str(accuracy))

evaluator = BinaryClassificationEvaluator()
print("Test Area Under ROC: " + str(evaluator.evaluate(predictions, {evaluator.metricName: "areaUnderROC"})))
# Out:
# Test Area Under ROC: 0.5205799362621079

# %%
from pyspark.ml.classification import LogisticRegression, OneVsRest
from pyspark.ml.evaluation import MulticlassClassificationEvaluator


# generate the train/test split.
(train_data, test_data) = pipe_df.randomSplit([0.7, 0.3])

# instantiate the base classifier.
lr = LogisticRegression(maxIter=5, tol=1E-6, fitIntercept=True)

# instantiate the One Vs Rest Classifier.
ovr = OneVsRest(classifier=lr)

# train the multiclass model.
ovrModel = ovr.fit(train_data)

# score the model on test data.
predictions = ovrModel.transform(test_data)

# obtain evaluator.
evaluator = MulticlassClassificationEvaluator(metricName="accuracy")

# compute the classification error on test data.
accuracy = evaluator.evaluate(predictions)
print("Test accuracy = %g" % (1.0 - accuracy))
# Out:
# Test accuracy = 0.15048

# %%
##Logistics Regression#### iteration 1
from pyspark.ml.classification import LogisticRegression

# Split our data. Note that the new DataFrame is being used.
train_data, test_data = pipe_df.randomSplit([0.7,0.3])
print("Training Dataset Count: " + str(train_data.count()))
print("Test Dataset Count: " + str(test_data.count()))

# Instantiate the model.
lr_model = LogisticRegression(featuresCol='features',labelCol='label')

# Fit the model.
lr_model = lr_model.fit(train_data)

# And evaluate the model using the test data.
predictions = lr_model.transform(test_data)

evaluator = MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction",metricName="accuracy")
accuracy = evaluator.evaluate(predictions)
print("Test set accuracy = " + str(accuracy))
# Out:
# Training Dataset Count: 199592
# Test Dataset Count: 85739
# Test set accuracy = 0.849695004607005

# %%
##Logistics Regression#### iteration 2
from pyspark.ml.classification import LogisticRegression

# Split our data. Note that the new DataFrame is being used.
train_data, test_data = pipe_df.randomSplit([0.6,0.4])
print("Training Dataset Count: " + str(train_data.count()))
print("Test Dataset Count: " + str(test_data.count()))

# Instantiate the model.
lr_model = LogisticRegression(featuresCol='features',labelCol='label')

# Fit the model.
lr_model = lr_model.fit(train_data)

# And evaluate the model using the test data.
predictions = lr_model.transform(test_data)

evaluator = MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction",metricName="accuracy")
accuracy = evaluator.evaluate(predictions)
print("Test set accuracy = " + str(accuracy))
# Out:
# Training Dataset Count: 171428
# Test Dataset Count: 113903
# Test set accuracy = 0.8497581275295646

# %%
##Logistics Regression#### iteration 3
from pyspark.ml.classification import LogisticRegression

# Split our data. Note that the new DataFrame is being used.
train_data, test_data = pipe_df.randomSplit([0.8,0.2])
print("Training Dataset Count: " + str(train_data.count()))
print("Test Dataset Count: " + str(test_data.count()))

# Instantiate the model.
lr_model = LogisticRegression(featuresCol='features',labelCol='label')

# Fit the model.
lr_model = lr_model.fit(train_data)

# And evaluate the model using the test data.
predictions = lr_model.transform(test_data)

evaluator = MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction",metricName="accuracy")
accuracy = evaluator.evaluate(predictions)
print("Test set accuracy = " + str(accuracy))
# Out:
# Training Dataset Count: 228343
# Test Dataset Count: 56988
# Test set accuracy = 0.8514950515898084

# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
print("Histograms below: ")

severity = df.groupBy('accident_severity').count().collect() 
categories = [i[0] for i in severity]
counts = [i[1] for i in severity]

ind = np.array(range(len(categories)))
width = 0.35
plt.bar(ind, counts, width=width, color='y')

plt.ylabel('counts')
plt.title('Response distribution')
plt.xticks(ind + width/2., categories)
# Out:
# Histograms below:
# ([<matplotlib.axis.XTick at 0x7f70824ed4a8>,
# ...
#  <a list of 3 Text xticklabel objects>)

# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
print("Histograms below: ")

speed = df.groupBy('speed_limit').count().collect() # list of Rows
categories = [i[0] for i in speed]
counts = [i[1] for i in speed]

ind = np.array(range(len(categories)))
width = 0.35
plt.bar(ind, counts, width=width, color='g')

plt.ylabel('counts')
plt.title('Response distribution')
plt.xticks(ind + width/2., categories)
# Out:
# Histograms below:
# ([<matplotlib.axis.XTick at 0x7f708251ca58>,
# ...
#  <a list of 8 Text xticklabel objects>)

# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
print("Histograms below: ")

age = df.groupBy('age_band_driver').count().collect() # list of Rows
categories = [i[0] for i in age]
counts = [i[1] for i in age]

ind = np.array(range(len(categories)))
width = 0.35
plt.bar(ind, counts, width=width, color='r')

plt.ylabel('counts')
plt.title('Response distribution')
plt.xticks(ind + width/2., categories)
# Out:
# Histograms below:
# ([<matplotlib.axis.XTick at 0x7f7081c5ee80>,
# ...
#  <a list of 4 Text xticklabel objects>)
